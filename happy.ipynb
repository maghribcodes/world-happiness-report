# %% [markdown]
# # Final Exam

# %% [markdown]
# #### Novisa Ardewati

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv
import seaborn as sns

# %%
happy =  pd.read_csv("2016.csv")
happy.head()
#happy.info()
# Out:
#        Country          Region  Happiness Rank  Happiness_Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %% [markdown]
# ## A. Happiness Score Wilayah Southeastern Asia

# %%
#tes = happy.loc[happy['Region']=='Southeastern Asia']

#dataframe=happy.loc[:5,["Happiness_Score"]]

#plt.figure(figsize=(15,10))
#parallel_coordinates(dataframe, 'Country', colormap=plt.get_cmap("Set1"))
#plt.title(" visualization according to year features (2016, 2017, 2018)")
#plt.xlabel("Features of data set")

#plt.show()

happy.Region = "Southeastern Asia"

data = pd.concat([happy],axis=0)
plt.figure(figsize=(20,8))
sns.swarmplot(x="Country", y="Happiness_Score", hue="Region", data=data, size=10)
plt.xticks(rotation=80)
plt.title("Happiness Scores in Southeastern Asia")
plt.xlabel("Country",color="orange")
plt.ylabel("Happiness Score",color="blue")
plt.show()

# %% [markdown]
# ## B. GDP vs Happiness Score 10 Country

# %%
tenCountry = happy.Country[:10]
unique = set(tenCountry) 
print(unique)

country_colors = {'Australia':'red',
                 'Sweden':'green',
                 'Netherlands':'aqua',
                 'Iceland':'blue',
                 'Denmark':'grey',
                 'Finland':'pink',
                 'Canada':'yellow',
                 'Switzerland':'orange',
                 'New Zealand':'purple',
                 'Norway':'olive'};

type(country_colors)

colors = []
for i in happy('Region'):
    
    colors.append(colors[i])

plt.clf()
plt.figure(figsize=(15,10))
plt.scatter(happy['Economy (GDP per Capita)'], happy['Happiness_Score'],  alpha=0.5, c=colors)
plt.grid(True)

plt.xlabel("GDP")
plt.ylabel("Happiness Score")
#plt.legend(country_colors)

plt.suptitle("GDP vs Happiness Score Ten Country", fontsize=18)

plt.show()
# Out:
# {'Canada', 'Finland', 'Norway', 'Sweden', 'New Zealand', 'Iceland', 'Netherlands', 'Denmark', 'Australia', 'Switzerland'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-33c192c1ed26> in <module>
#      17
#      18 colors = []
# ---> 19 for i in happy('Region'):
#      20
#      21     colors.append(colors[i])
#
# TypeError: 'DataFrame' object is not callable

# %%
fig, ax = plt.subplots(figsize=(8, 6.5))
n = happy.Country[:10]
g = sns.scatterplot('Economy (GDP per Capita)', 'Happiness_Score',  hue= n , data=happy);
g.legend(loc='upper left', bbox_to_anchor=(1.05, 1.01), ncol=1);

# %% [markdown]
# ## C. Happiness Score Mean By Region

# %%
happy.Region.unique()

region_lists=list(happy['Region'].unique())
region_happiness_ratio=[]
for each in region_lists:
    region=happy[happy['Region']==each]
    region_happiness_rate=sum(region.Happiness_Score)/len(region)
    region_happiness_ratio.append(region_happiness_rate)
    
data=pd.DataFrame({'region':region_lists,'region_happiness_ratio':region_happiness_ratio})
new_index=(data['region_happiness_ratio'].sort_values(ascending=False)).index.values
sorted_data = data.reindex(new_index)

sorted_data

plt.figure(figsize=(12,10))
sns.barplot(x=sorted_data['region'], y=sorted_data['region_happiness_ratio'],palette=sns.cubehelix_palette(len(sorted_data['region'])))

plt.xticks(rotation= 90)
plt.xlabel('Region')
plt.ylabel('Region Happiness Ratio')
plt.title('Happiness rate for regions')
plt.show()
